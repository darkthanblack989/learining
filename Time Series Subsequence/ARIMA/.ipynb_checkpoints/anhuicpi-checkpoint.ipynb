# %%
import pandas as pd
from datetime import datetime
from matplotlib import pyplot
import warnings
warnings.simplefilter(action="ignore", category=FutureWarning)

# %%
series = pd.read_excel(r'C:\Users\Administrator\Desktop\test\anhuicpi.xlsx', header=0, parse_dates=[0], index_col=0)
print(series.head())
series.plot()
pyplot.show()
# Out:
#                  cpi
# time
# 2017-12-01  101.3522
# 2018-01-01  101.4218
# 2018-02-01  103.2000
# 2018-03-01  101.7085
# 2018-04-01  101.0774
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13364\2241759688.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   series = pd.read_excel(r'C:\Users\Administrator\Desktop\test\anhuicpi.xlsx', header=0, parse_dates=[0], index_col=0)

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
pyplot.show()

# %%
import statsmodels.api as sm
series = pd.read_excel(r'C:\Users\Administrator\Desktop\test\anhuicpi.xlsx', header=0, parse_dates=[0], index_col=0)
# fit model
model = sm.tsa.ARIMA(series, order=(4, 0, 0), freq = None).fit()
print(model.summary())
# plot residual errors
residuals = pd.DataFrame(model.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13364\673045087.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   series = pd.read_excel(r'C:\Users\Administrator\Desktop\test\anhuicpi.xlsx', header=0, parse_dates=[0], index_col=0)
# C:\software\Anaconda3\envs\ARIMA\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\software\Anaconda3\envs\ARIMA\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\software\Anaconda3\envs\ARIMA\lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                    cpi   No. Observations:                   76
# Model:                 ARIMA(4, 0, 0)   Log Likelihood                 -75.033
# Date:                Sun, 12 May 2024   AIC                            162.066
# Time:                        10:22:51   BIC                            176.051
# Sample:                    12-01-2017   HQIC                           167.655
#                          - 03-01-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        101.5066      0.661    153.586      0.000     100.211     102.802
# ar.L1          0.9781      0.110      8.930      0.000       0.763       1.193
# ar.L2         -0.1520      0.192     -0.790      0.430      -0.529       0.225
# ar.L3         -0.0360      0.222     -0.163      0.871      -0.470       0.398
# ar.L4          0.0852      0.139      0.611      0.541      -0.188       0.359
# sigma2         0.4135      0.074      5.606      0.000       0.269       0.558
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 1.38
# Prob(Q):                              0.99   Prob(JB):                         0.50
# Heteroskedasticity (H):               0.91   Skew:                             0.30
# Prob(H) (two-sided):                  0.81   Kurtosis:                         3.26
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
#                0
# count  76.000000
# mean    0.000258
# std     0.648003
# min    -1.467946
# 25%    -0.389743
# 50%     0.020905
# 75%     0.349260
# max     1.773619

# %%
from sklearn.metrics import mean_squared_error

# %%
x = series.values
size = int(len(x) * 0.8)
train, test = x[0:size], x[size:len(x)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
    model = sm.tsa.ARIMA(history, order=(4, 0, 0), freq = None).fit()
    output = model.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# predicted=101.193677, expected=101.300000
# predicted=101.576829, expected=101.600000
# predicted=101.769546, expected=100.800000
# predicted=100.800599, expected=100.400000
# predicted=100.704887, expected=99.700000
# predicted=99.957022, expected=100.000000
# predicted=100.485193, expected=99.900000
# predicted=100.177372, expected=99.400000
# predicted=99.639173, expected=99.900000
# predicted=100.365981, expected=99.900000
# predicted=100.110249, expected=99.800000
# predicted=100.037342, expected=99.600000
# predicted=99.829990, expected=100.000000
# predicted=100.328220, expected=99.400000
# predicted=99.489748, expected=100.800000
# predicted=101.202708, expected=99.900000
# Test MSE: 0.497
